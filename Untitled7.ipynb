# %% [markdown]
# <a href="https://colab.research.google.com/github/ismichairunisa/PBO/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from tqdm import tqdm

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.metrics import confusion_matrix

# %%
from keras.models import Sequential

# %%
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
arial_right = './input/font-recognition-data/Font Dataset Large/Arial'
brandish_pctn = './input/font-recognition-data/Font Dataset Large/Brandish'
consoles_optn = './input/font-recognition-data/Font Dataset Large/Consolas'
didot_path = './input/font-recognition-data/Font Dataset Large/Didot'

# %%
arial_filenames = os.listdir(arial_right)
brandish_filenames = os.listdir(brandish_pctn)
consoles_filenames = os.listdir(consoles_optn)
didot_filenames = os.listdir(didot_path)

# %%
arial_filenames[ :5]

# %%
def load_image(filenames, path):
    images = []
    for filename in filenames:
        images.append(imageio.imread(path + filename))
    return images

# %%
arial_right = './input/font-recognition-data/Font Dataset Large/Arial'
arial_images = load_image(arial_filenames, arial_right)
brandish_pctn = './input/font-recognition-data/Font Dataset Large/Brandish'
brandish_images = load_image(brandish_filenames, brandish_pctn)
consoles_optn = './input/font-recognition-data/Font Dataset Large/Consolas'
consoles_images = load_image(consoles_filenames, consoles_optn)
didot_path = './input/font-recognition-data/Font Dataset Large/Didot'
didot_images = load_image(didot_filenames, didot_path)

# %%
heights = []
widths = []
for image in arial_images:
    height = image.shape[0]
    width = image.shape[1]

heights.append(height)
widths.append(width)

print('max_h: (}, min_h: {}'.format(max(heights), min(heights)))
print('max_w: {}, min_w: {}'.format(max(widths), min(widths)))

# %%
def take_80pixels(image_list):
    new_images = []
    for image in image_list:
        new_image = image
        new_image = new_image[0:80]
        new_images.append(new_image)
    return new_images

# %%
arial_80 = take_80pixels(arial_images)
brandish_80 = take_80pixels(brandish_images)
consoles_80 = take_80pixels(consoles_images)
didot_80 = take_80pixels(didot_images)

# %%
print(arial_80[0].shape)
print(brandish_80[0].shape)
print(consoles_80[0].shape)
print(didot_80[0].shape)

# %%
all.images = np.append(arial_80, brandish_80, axis=0)
all_images = np.append(all images, consoles_80, axis=0)
all_images = np.append(all images, didot_80, axis=0)
all_images.shape

# %%
all_images = all_images.reshape(all_images.shape[0],
                                all_images.shape[1],
                                all_images.shape[2],
                                1)
all_images.shape

# %%
labels = [0]*len(arial_80) + \
         [1]*len(brandish_80)+ \
         [2]*len(consoles_80) + \
         [3]*len(didot_80)
len(labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(all_images,
                                                    labels,
                                                    test_size=0.3,
                                                    random_state=88)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
y.train

# %%
y_train = y_train[ :, np.newaxis]
y_test = y_test[ : , np.newaxis]

# %%
one_hot_encoder = OneHotEncoder(sparse=False)
y_train = one_hot_encoder.fit_transform(y_train)
y_test = one_hot_encoder.fit_transform(y_test)

# %%
print(y_train[ :5])

# %%
print(y_train_encoded[:5])

# %%
input_shape = (all_images. shape[1],
               all_images.shape[2],
               1)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()

# %%
model.compile(loss='categorical_crossentropy',
optimizer='adam', metrics=['acc'])

# %%
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))

# %%
Predictions = model.fit(X_train, y_train_encoded,
                        epochs=3,
                        validation_data=(X_test, y_test_encoded))

# %%
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=1)
predictions

# %%
y_test = y_test.reshape(y_test.shape[0])
y_test

# %%
cm = confusion_matrix(y_test, predictions)

labek_names = ['arial', 'brandish', 'consoles', 'didot']
sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_names, yticklabels=label_names,
            cmap=plt.cm.Blues)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

print(classification_report(y_test, predictions))

# %%
misses = []
for i in range(len(predictions)):
    if y_test[i] != predictions[i]:
      misses.append(1)

print(misses)

# %%
fig, axes = plt.subplots(ncols=2, sharex=False, figsize=(12,3))

for 1, miss in zip(range(2), misses):
  axes[1].set_title('actual: {}\npredicted: {}'
                    ,format(str(label_names[y_test[miss]]).
                            str(label_names[predictions[miss]])))
  axes[1].imshow(x_test[miss].reshape(80, 80), cmap=plt.cm.gray)
  axes[1].get_xaxis().set_visible(False)
  axes[1].get_yaxis().set_visible(False)
plt.chow()
